# %%
from dotenv import load_dotenv

import os

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Construção de Tools
#
# A construção de Tools com o objeto ``Structuredtool`` é importante devido a sua capacidade de ser compatível com as cadeias do ``Langchain``. Isso promove uma série de benefícios, como suporte para ``paralelização``, ``reutilização``, ``observabilidade``, ``monitoramento`` e outros.
#
# Para a construção das ferramentas, podemos utilizar o código abaixo, o exemplo que vamos utilizar será reutilizado para construir uma ferramenta de agente que irá pesquisar tendências via ``Google Trends`` e retornará uma lista de conteúdos que estão em alta.

# %%
# Importar a biblioteca necessária
from pytrends.request import TrendReq
from langchain_core.tools import StructuredTool

# Inicializar um objeto TrendReq
pytrends = TrendReq(hl='pt-BR', tz=360)

def trends_per_country(country: str, head: int) -> str:
    """trends per country"""
    country = country.lower()
    daily_trending_searches = pytrends.trending_searches(pn=country)
    word_list = daily_trending_searches.head(head).values.T[0]
    return "\n".join(word_list)


async def atrends_per_country(country: str, head: int) -> str:
    """trends per country"""
    country = country.lower()
    daily_trending_searches = pytrends.trending_searches(pn=country)
    word_list = daily_trending_searches.head(head).values.T[0]
    return "\n".join(word_list)

def create_trends_tool():
    return StructuredTool.from_function(func=trends_per_country, coroutine=atrends_per_country)

trends = create_trends_tool()

print(trends.invoke({"country": "brazil", "head": 10}))
print("--------------------------------")
print(
    await trends.ainvoke({"country": "united_states", "head": 10})
)  # Uses use provided amultiply without additional overhead
# Out:
# IBFC Correios
# André Feldman
# UFC
# Al Nassr
# Eintracht x Borussia
# Roma x Genoa
# Benfica x Famalicão
# VALE3
# Univ de Chile x River Plate
# Vasco Copinha
# --------------------------------
# UFC
# Kristi Noem
# Equal Rights Amendment
# Dodgers
# Mac Miller
# Back in Action
# Joan Plowright
# Opera
# Edge
# Unrivaled basketball

# %% [markdown]
# ## Construção de Tools com o Serper
#
# Aqui vamos construir outra ferramenta que irá pesquisar as tendências geradas pelo pytrends da etapa anterior. Abaixo você vai encontrar uma função que recebe uma lista de queries e retorna uma lista de notícias que foram retornadas pelo ``GoogleSerperAPIWrapper`` (Pesquise sobre o Serper para entender melhor).
#
# Por fim, vamos acompanhar o código que será utilizado para construir a ferramenta.

# %%
from typing import List
import os

from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_community.document_loaders import WebBaseLoader
from tqdm import tqdm

def get_serper_results(queries: List[str],
                       k: int=5,
                       type_content: str='news',
                       hl: str='pt',
                       gl: str='br') -> List[dict]:
    
    """
    Get the multiple search results from Google Serper API
    
    Args:
    - queries: List of queries to be searched
    - k: Number of results to be returned
    - type_content: Type of content to be searched
    - hl: Language to be searched
    - gl: Country to be searched
    
    Returns:
    - List of results from the search
    
    """

    search = GoogleSerperAPIWrapper(gl=gl,
                                    hl=hl,
                                    k=k, 
                                    type=type_content) # type: Literal['news', 'search', 'places', 'images'] = 'search'
    
    results = [search.results(query) for query in queries]
    return results

def get_serper_with_scrapping(queries: List[str],
                              k: int=5,
                              type_content: str='news',
                              hl: str='pt',
                              gl: str='br') -> List[dict]:
    
    """
    Get the multiple search results from Google Serper API and scrap the content
    
    Args:
    - queries: List of queries to be searched
    - k: Number of results to be returned
    - type_content: Type of content to be searched
    - hl: Language to be searched
    - gl: Country to be searched
    
    Returns:
    - List of results from the search
    
    """
    requests_kwargs = {
    'timeout': 5  # Define o timeout para 5 segundos
    }
    
    results = get_serper_results(queries, 
                                 k, 
                                 type_content, 
                                 hl, 
                                 gl)
    
    dict_results_news = {}
    for r in tqdm(results):
        q = r['searchParameters']['q']
        news = r['news']
        
        for i in range(len(news)):
            n = news[i]
            link = n['link']
            loader = WebBaseLoader(web_paths=[link],
                                    requests_kwargs=requests_kwargs) # Adiciona timeout
            docs = loader.load()
            news[i]['content'] = "\n".join([x.page_content for x in docs])
        
        dict_results_news[q] = news
        
    return dict_results_news
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
def to_list(text):
    return text.split("\n")

trends_text = trends.invoke({"country": "brazil", 
                             "head": 3})
trends_list = to_list(trends_text)
trends_list
# Out:
# ['IBFC Correios', 'André Feldman', 'UFC']

# %%
contents_news = get_serper_with_scrapping(trends_list, k=5)
# Out:
# 100%|██████████| 3/3 [00:15<00:00,  5.31s/it]

# %%
contents_news
# Out:
# {'IBFC Correios': [{'title': '"Sem previsão", diz banca sobre resultado do concurso dos Correios',
#    'link': 'https://www.metropoles.com/brasil/sem-previsao-diz-banca-sobre-resultado-do-concurso-dos-correios',
#    'snippet': 'Concurso dos Correios foi realizado em dezembro do último ano e oferece 3,5 mil vagas de nível médio e superior.',
#    'date': '3 dias atrás',
#    'source': 'Metrópoles',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQxtuFpEc5BgT-ULyTHMf5c22b_V3moofeWF2qsS8aBR-plGAj3qWzAYbk&usqp=CAI&s',
#    'position': 1,
#    'content': '“Sem previsão”, diz banca sobre resultado do concurso dos Correios | MetrópolesNotificaçõesMetropólesmetropoles.comAssine nossas newslettersBuscametropoles.comÚltimas notíciasBrasilDistrito FederalSão PauloMundoSaúdeVida & EstiloGrande AngularBlog do NoblatIgor GadelhaMario SabinoPaulo CappelliTácio LorranClaudia MeirelesFábia OliveiraViolência contra a mulherEntretenimentoCelebridadesGastronomiaRádio MetrópolesEsportesConcursos & EmpregosEconomiaNegóciosÉ o bicho!ColunasWeb StoriesMentorReportagens especiaisParceirosApostasQuem somosExpedienteTermos de usoAnunciePost PatrocinadoParceirosFale com o Metrópolesmetropoles.comFecharDigite sua buscaBuscarÚltimasBrasilDFSPBlog do NoblatIgor GadelhaMario SabinoPaulo CappelliTácio LorranClaudia MeirelesEntretenimentoVida & EstiloSaúdeEsportesEspeciaisPágina inicialBrasilBrasil“Sem previsão”, diz banca sobre resultado do concurso dos CorreiosConcurso dos Correios foi realizado em dezembro do último ano e oferece 3,5 mil vagas de nível médio e superiorJunio Silva14/01/2025 14:29, atualizado 14/01/2025 15:43Compartilhar notíciaGoogle News - MetrópolesReprodução\n 1 de 1 Imagem colorida, sede dos Correios - Metrópoles\n        - Foto: ReproduçãoApesar da expectativa pela divulgação dos resultados da prova objetiva do concurso dos Correios, ainda não há previsão para a publicação dos dados. A informação foi confirmada ao Metrópoles pelo Instituto Brasileiro de Formação e Capacitação (IBFC), banca responsável pelo certame.\nMegaconcurso dos Correios\n\nO concurso dos Correios foi realizado em dezembro de 2024, e ofertou 3,5 mil vagas.\nAo todo, 1,6 milhão de candidatos participaram do certame, que oferece vagas de nível médio e superior.\xa0\nOs salários iniciais vão de R$ 2.429,26 a R$ 10.302.\n\n\nLeia também\n\n\n\n\nBrasil\n\n\nConcurso dos Correios: resultado é adiado e não deve sair nesta 3ª\n\n\n\n\n\n\nBrasil\n\n\nCorreios: sai o gabarito preliminar do concurso. Veja como consultar\n\n\n\n\n\n\nBrasil\n\n\nConcurso dos Correios com 3,5 mil vagas é neste domingo; saiba tudo\n\n\n\n\n\n\nBrasil\n\n\nConcurso dos Correios: saiba como consultar seu local de provas\n\n\n\n\n\nA divulgação dos resultados da prova objetiva estava prevista para acontecer em até 30 dias após a aplicação das provas. A data seria nesta terça-feira (14/1). \nQuestionado pelo Metrópoles, o IBFC afirmou que os resultados “provavelmente” não serão publicados nesta terça.\n\xa0\n\xa0\nReceba notícias do Metrópoles no seu Telegram e fique por dentro de tudo! Basta acessar o canal de notícias no Telegram.Quem somosExpedienteTermos de usoAnunciePost PatrocinadoParceirosFale com o MetrópolesConfiguração de privacidadeTodos os direitos reservadosQuais assuntos você deseja receber?Notícias GeraisBrasilDistrito FederalSão PauloEsportesVida & EstiloSaúdeGastronomiaCelebridadesEntretenimentoPetsConfirmarParece que seu browser não está permitindo notificações. Siga os passos a baixo para habilitá-las:1. Mais opções no Google Chrome2. Configurações3. Configurações do site4. Notificações5. Os sites podem pedir para enviar notificaçõesvoltarmetropoles.comVocê quer ficar por dentro das notícias mais importantes e receber notificações em tempo real?Eu quero!Agora não'},
#   {'title': 'Concurso Correios: confira o resultado final da prova!',
#    'link': 'https://www.novaconcursos.com.br/portal/noticias/concurso-correios-resultado/',
#    'snippet': 'O concurso Correios poderá ter resultado final das provas divulgadas em breve! As vagas do edital são destinadas para níveis médio e...',
#    'date': '3 dias atrás',
#    'source': 'Nova Concursos',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQOXlx-kJF5_2BJ8gx5iRxXaCFJHUQnS8t4QQzr3fxSPbGMCxp1RCZravw&usqp=CAI&s',
#    'position': 2,
#    'content': '\n\n\n\n\nConcurso Correios: resultado das provas\xa0em\xa02\xa0semanas!\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                Assinatura completa\n            \n\n\n\n\n\n\n\n\n\n            ASSINATURA COMPLETA\n        \n\n\n\n\n\n                Concursos\n                \n\n\n \n\n\n\nApostilas\n\n\nCursos\n\n\nLivros\n\n\nCursos grátis\n\n\nConcursos Abertos\n\n\n\n                Blog\n                \n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n                    Quem somos\n                \n\n\n\n                    Termos de uso\n                \n\n\n\n                    Política de privacidade\n                \n\n\n\n                    Perguntas frequentes\n                \n\n\n\n                    Central de atendimento\n                \n\n\n\n\n\n\n                Acompanhe nossas Redes Sociais\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                    Menu\n                    \n\n\n\n                Preparar-se por:\n            \n\n\n\n                    Concurso\n                                            \n\n\n\n\n\n                    Carreira\n                                            \n\n\n\n\n\n                    Estado\n                                            \n\n\n\n\n\n                    Banca\n                                            \n\n\n\n\n\n\n\n\n\n\n\n                Menu\n            \n\n\n\n\n\n\n\n\n\n\n \nCConcursosConteúdo atualizado e completo sobre os principais concursos do país.\nNNotíciasFique por dentro de oportunidades e movimentações sobre concursos\nAArtigosArtigos elaborados por nossos especialistas\nTTeoriaConteúdos gratuitos para te ajudar a sair do zero e conquistar a aprovaçao\nCCargos públicosDescubra qual é o cargo ideal para você se preparar\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n                    Assinatura completa\n                \n\n\n\nEntrar\n\n\n\n4\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                Apostilas\n                            \n\n\n\n                                Cursos\n                            \n\n\n\n                                Livros\n                            \n\n\n\nCursos grátis\n\n\n\n\n                                Concursos Abertos\n                            \n\n\n\n                                Mapas Mentais\n                            \n\n\n\n                                Mapa de Questões\n                            \n\n\n                            Blog\n                            \n\n\n\n\n\n\n\n\n\n\n\n                Preparar-se por:\n            \n\n\n\n                    Concurso\n                                        \n\n\n                    Carreira\n                                        \n\n\n                    Estado\n                                        \n\n\n                    Banca\n                                        \n\n\n\n\n\n\n\n\n\n\n\n\n\n \nCConcursosConteúdo atualizado e completo sobre os principais concursos do país.\nNNotíciasFique por dentro de oportunidades e movimentações sobre concursos\nAArtigosArtigos elaborados por nossos especialistas\nTTeoriaConteúdos gratuitos para te ajudar a sair do zero e conquistar a aprovaçao\nCCargos públicosDescubra qual é o cargo ideal para você se preparar\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\nInício > Notícias > Concurso Correios: resultado das provas\xa0em\xa02\xa0semanas! \n\n\n\n\n\n\n        Índice\n    \n\nConcurso Correios terá resultado das provas divulgado em breve!\nSão 3.511 vagas ofertadas para níveis médio e superior\nConfira os benefícios dos servidores dos Correios\nRequisitos para a nomeação dos candidatos aprovados no edital Correios\n\n\n\n\n\n\n\n        Concurso Correios: resultado das provas\xa0em\xa02\xa0semanas!    \n\n\n        O concurso Correios teve as provas aplicadas em dezembro do ano pa ...
#   {'title': 'Sai resultado preliminar de concurso para carteiro dos Correios',
#    'link': 'https://agenciabrasil.ebc.com.br/geral/noticia/2025-01/sai-resultado-de-concurso-para-carteiro-dos-correios',
#    'snippet': 'Já está disponível no site do Instituto Brasileiro de Formação e Capacitação (IBFC) o resultado preliminar das provas objetivas do concurso...',
#    'date': 'há 12 horas',
#    'source': 'Agência Brasil',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4wGOwftIxBlQcSOY_wINC-wr5KpaM0TiucZo7wac1bAKLtcnTJKyBPXs&usqp=CAI&s',
#    'position': 3,
#    'content': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCorreios: sai resultado preliminar de concurso para carteiro | Agência Brasil\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPular para o conteúdo principal\n\n\n\n\n\n\n\nagênciaBrasil\nradioAgência\nrádioMEC\nrádioNacional\ntvBrasil\n|\ncarta de serviços\n|\ntransparência\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nA+\nA-\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOR\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOR - Português\nENG - English\nESP - Español\n\n\n\n\n\n\n\n\n\n\n\n\n\nMenu\n\n\nA+\nA-\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOR\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOR - Português\nENG - English\nESP - Español\n\n\n\n\n\n\nInício\n\n\n\n\n\n\nÚltimas Notícias\n\n\n\n\n\n\nFoto Agência\n\n\n\n\n\n\nEspecial\n\n\n\n\n\n\nRadioagência Nacional\n\n\n\n\n\n\nTabelas\n\n\n\n\n\n\nFeed Rss\n\n\n\n\n\n\nWhatsapp\n\n\n\n\n\n\nSobre\n\n\n\n\n\n\n\nCultura\n\n\n\n\n\nDireitos Humanos\n\n\n\n\n\nEconomia\n\n\n\n\n\nEducação\n\n\n\n\n\nEsportes\n\n\n\n\n\nGeral\n\n\n\n\n\nInternacional\n\n\n\n\n\nJustiça\n\n\n\n\n\nMeio Ambiente\n\n\n\n\n\nPolítica\n\n\n\n\n\nSaúde\n\n\n\n\n\n\n\n\n\nÚltimas Notícias\n|\nCultura\nDireitos Humanos\nEconomia\nEducação\nEsportes\nGeral\nInternacional\nJustiça\nMeio Ambiente\nPolítica\nSaúde\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nGeral\n\n        Correios: sai resultado preliminar de concurso para carteiro      \n  Salário inicial é R$ 2,4 mil, com vale-alimentação de R$ 1,4 mil\n\n\n\n\n            Pedro Peduzzi - Repórter da Agência Brasil        \n\nPublicado em   17/01/2025 - 11:05\n\n\n  Brasília\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© Joédson Alves/Agência Brasil\n\n \n\n\n\n\nVersão em áudio\n\n\n\n\n\nJá está disponível\xa0no site do Instituto Brasileiro de Formação e Capacitação (IBFC)\xa0o resultado preliminar das provas objetivas do concurso público dos Correios, para 3.099 vagas ofertadas aos candidatos ao cargo de Agente de Correios – Carteiro (nível médio).\nCerca de 1 milhão de candidatos concorreram a 3.511 vagas para carteiro e outros cargos. O concurso\xa0para a empresa pública foi aplicado\xa0no dia 15 de dezembro de 2024, após 13 anos de suspensão.\nOs cargos de nível médio para carteiro terão salário inicial de R$ 2,4 mil, além de vale-alimentação/refeição de cerca de R$ 1,4 mil.\nO resultado preliminar das provas objetivas para as 412 vagas para cargos de nível superior (analista de correios, com salário inicial de R$ 6,87 mil) será publicado no dia 24 de janeiro. Neste caso, com os benefícios, a remuneração total fica em cerca de R$ 8,5 mil. As especialidades previstas no edital são para advogado, analista de sistemas, arquiteto, arquivista, assistente social e engenheiro.\nAo menos\xa030% das vagas são destinadas para pessoas negras (pretas e pardas) e indígenas, quantitativo superior ao estabelecido pela legislação (20%), e 10% para pessoas com deficiência.\n\n\nRelacionadas\n\n\n\n\n\n                    Brasil está entre os países que mais usam inteligência artificial                  \n\n\n\n\n\n\n                    Governo do Rio anuncia R$ 8 bilhões para enfrentamento de temporais                  \n\n\n\n\n\n\n                    Prefeitura de São Paulo começa a apreender mototáxis                   \n\n\n\n\n\n\nEdição: \n  Maria Claudia\n\n\nCorreios\nresultado de concurso\ncarteiro\n\n\n\nCompartilhe essa notícia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContinuar lendo\n\n\n\n\n\n\n\n\nDestaques EBC\n\n\n\nRadioagência\nAssentados de Tremembé serão incluídos em programa de proteção\n\n\nRádios\nRepórter Nacional 18h30: aposentadorias não vão ser suspensas por falta de prova de vida\n\n\nTV Brasil\nChuva no Piauí: rios e açudes estão com nível acima do normal\n\n\n\n\n\n\n\ ...
#   {'title': 'Concurso Correios: confira o resultado final das provas!',
#    'link': 'https://www.novaconcursos.com.br/portal/noticias/concurso-correios-resultado-final-carteiro/',
#    'snippet': 'O concurso Correios tem os resultados finais das provas objetivas de Carteiro divulgados pela banca IBFC. Confira aqui!',
#    'date': 'há 8 horas',
#    'source': 'Nova Concursos',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7xpRzz1uN_73tDrXx6VX7iX9Pt9Pvov2b_EIjxTa1ZDO7S_3p6LoPqCY&usqp=CAI&s',
#    'position': 4,
#    'content': '\n\n\n\n\nConcurso Correios: publicado o resultado preliminar das provas objetivas!\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                Assinatura completa\n            \n\n\n\n\n\n\n\n\n\n            ASSINATURA COMPLETA\n        \n\n\n\n\n\n                Concursos\n                \n\n\n \n\n\n\nApostilas\n\n\nCursos\n\n\nLivros\n\n\nCursos grátis\n\n\nConcursos Abertos\n\n\n\n                Blog\n                \n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n                    Quem somos\n                \n\n\n\n                    Termos de uso\n                \n\n\n\n                    Política de privacidade\n                \n\n\n\n                    Perguntas frequentes\n                \n\n\n\n                    Central de atendimento\n                \n\n\n\n\n\n\n                Acompanhe nossas Redes Sociais\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                    Menu\n                    \n\n\n\n                Preparar-se por:\n            \n\n\n\n                    Concurso\n                                            \n\n\n\n\n\n                    Carreira\n                                            \n\n\n\n\n\n                    Estado\n                                            \n\n\n\n\n\n                    Banca\n                                            \n\n\n\n\n\n\n\n\n\n\n\n                Menu\n            \n\n\n\n\n\n\n\n\n\n\n \nCConcursosConteúdo atualizado e completo sobre os principais concursos do país.\nNNotíciasFique por dentro de oportunidades e movimentações sobre concursos\nAArtigosArtigos elaborados por nossos especialistas\nTTeoriaConteúdos gratuitos para te ajudar a sair do zero e conquistar a aprovaçao\nCCargos públicosDescubra qual é o cargo ideal para você se preparar\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n                    Assinatura completa\n                \n\n\n\nEntrar\n\n\n\n4\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                Apostilas\n                            \n\n\n\n                                Cursos\n                            \n\n\n\n                                Livros\n                            \n\n\n\nCursos grátis\n\n\n\n\n                                Concursos Abertos\n                            \n\n\n\n                                Mapas Mentais\n                            \n\n\n\n                                Mapa de Questões\n                            \n\n\n                            Blog\n                            \n\n\n\n\n\n\n\n\n\n\n\n                Preparar-se por:\n            \n\n\n\n                    Concurso\n                                        \n\n\n                    Carreira\n                                        \n\n\n                    Estado\n                                        \n\n\n                    Banca\n                                        \n\n\n\n\n\n\n\n\n\n\n\n\n\n \nCConcursosConteúdo atualizado e completo sobre os principais concursos do país.\nNNotíciasFique por dentro de oportunidades e movimentações sobre concursos\nAArtigosArtigos elaborados por nossos especialistas\nTTeoriaConteúdos gratuitos para te ajudar a sair do zero e conquistar a aprovaçao\nCCargos públicosDescubra qual é o cargo ideal para você se preparar\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\nInício > Notícias > Concurso Correios: publicado o resultado preliminar das provas objetivas! \n\n\n\n\n\n\n        Índice\n    \n\nConcurso Correios: resultado preliminar das provas objetivas \nConcurso Correios tem edital retificado\nResumo do concurso Correios\n\n\n\n\n\n\n\n        Concurso Correios: publicado o resultado preliminar das provas objetivas!    \n\n\n        O concurso Correios tem resultado preliminar das provas objetivas divulgado, juntamente com o cronograma das próximas etapas para os cargo ...
#   {'title': 'Concurso dos Correios: resultado preliminar é divulgado; veja como acessar',
#    'link': 'https://g1.globo.com/trabalho-e-carreira/concursos/noticia/2025/01/17/concurso-dos-correios-resultado-preliminar-e-divulgado-veja-como-acessar.ghtml',
#    'snippet': 'Os resultados preliminares das provas objetivas do concurso público dos Correios, para o cargo de carteiro, foram divulgados nesta...',
#    'date': 'há 15 horas',
#    'source': 'g1 - O portal de notícias da Globo',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQSJPxjSl1njwl7W5VOTNaVOue6nCUSqziRlDPpcitzTu0VSePzQLwt5jU&usqp=CAI&s',
#    'position': 5,
#    'content': ' Concurso dos Correios: resultado preliminar é divulgado; veja como acessar | Concursos | G1\n                   Trabalho e Carreira       Concursos                                   Concurso dos Correios: resultado preliminar é divulgado; veja como acessar     Mais de 1 milhão de pessoas realizaram as provas em dezembro. A seleção vai preencher 3.511 vagas imediatas em todos os estados brasileiros, com salários iniciais de até R$ 6,8 mil.              Por Redação g1 — São Paulo    17/01/2025 08h01    Atualizado  17/01/2025                                                  1 de 1\rConcurso dos Correios oferece mais de 3 mil vagas de nível médio e superior — Foto: Joédson Alves/Agência Brasil     Concurso dos Correios oferece mais de 3 mil vagas de nível médio e superior — Foto: Joédson Alves/Agência Brasil                Os resultados preliminares das provas objetivas do concurso público dos Correios, para o cargo de carteiro, foram divulgados nesta sexta-feira (17).       ✅ Clique aqui para seguir o canal do g1 Concursos no WhatsApp      As informações estão disponíveis no site dos Correios e do Instituto Brasileiro de Formação e Capacitação (IBFC), a banca responsável pela organização do processo seletivo.       Para o cargo de analista de Correios, de nível superior, o resultado preliminar e o gabarito definitivo serão divulgados no dia 24 de janeiro.      ➡️ Acesse os gabaritos oficiais do concurso dos Correios       Além disso, o resultado da análise dos recursos contra as questões da prova objetiva do cargo de carteiro já está disponível (entenda como é feita a contestação das questões ou respostas).             De acordo com a banca, não houve recursos procedentes. Por isso, o gabarito agora é definitivo.       O resultado do procedimento de heteroidentificação (para pretos, pardos e indígenas) e a avaliação para pessoas com deficiência, que concorrem no cargo de carteiro, também estão disponíveis.      Veja o edital do Resultado Preliminar da Prova Objetiva - CarteiroVeja o edital do Resultado Preliminar da Prova Objetiva - Nível Superior       Mais de 1 milhão de pessoas realizaram as provas do concurso em dezembro. Esse é o maior concurso da estatal nos últimos 13 anos.       O número de inscritos nesta edição foi de 1,6 milhão, o que faz com que a taxa de comparecimento tenha sido de 59,85%.       O total de inscritos foi maior que o último concurso nacional da empresa em 2011, quando 1,1 milhão de pessoas se cadastraram para mais de 9 mil oportunidades.      📬 Mais de 3 mil vagas       A seleção vai preencher 3.511 vagas imediatas, com salários iniciais de até R$ 6,8 mil. As oportunidades foram divididas em dois editais:      3.099 vagas são para o cargo de carteiro (agente de Correios), com salário inicial de R$ 2.429,26. Para a carreira, que é de nível médio, concorrem 93% (1.560.704) dos inscritos.412 oportunidades são para analista de Correios, de nível superior, e têm salários iniciais de R$ 6.872,48. Cerca de candidatos 111.967 concorrem aos cargos de advogado, analista de sistemas, arquiteto, arquivista, assistente social e engenheiro.             Do total de vagas a serem preenchidas, 30% são reservadas para negros (pretos e pardos) e indígenas, e 10% para pessoas com deficiência.       Além da remuneração, que aumenta conforme o tempo de serviço e o mérito do funcionário, os Correios oferecem uma série de benefícios que ajudam a complementar a renda dos trabalhadores selecionados, como:      Vale-alimentação/refeição: quase R$ 1,4 mil por mês.Vale-transporte: disponível para todos os funcionários.Plano de saúde: possibilidade de adesão.Auxílio-creche/auxílio-babá: até R$ 714,72 para empregadas com filhos menores de 7 anos.Reembolso de despesas para filhos dependentes de cuidados especiais: até R$ 1.030,58.Adicional de atividades externas: 30% do salário-base (inicialmente R$ 728).Adicional por serviço no fim de semana: 15% do salário-base pelas horas trabalhadas.Gratificação de "quebra de cai ...
#  'André Feldman': [{'title': 'Empresário morto em queda de helicóptero em SP era sócio de empresa de apostas virtual',
#    'link': 'https://www.estadao.com.br/sao-paulo/empresario-morto-em-queda-de-helicoptero-em-sp-era-socio-de-empresa-de-apostas-virtual-nprm/',
#    'snippet': 'André Feldman era conhecido na cidade de Americana, no interior do Estado. Ele e esposa, Juliana Elisa Maria Feldman, morreram no acidente.',
#    'date': 'há 13 horas',
#    'source': 'Estadão',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZgSVefiVIAlif0L799BW7zpkTmZGnnW6IuoC_TPo&usqp=CAI&s',
#    'position': 1,
#    'content': 'Quem era o casal que morreu em queda de helicóptero em Caieiras, na Grande SP - Estadão\n\n AssineNotícias & EditoriasOpiniãoÚltimasEstadão 150 Anos150 MomentosModernizar a históriaTodo o futuro pela frenteOpinião do EstadãoNossos queridos leitoresPolíticaColuna do EstadãoBlog do Fausto MacedoBlogs&ColunasEconomiaAgronegóciosEstadão RIGovernançaIndicadoresNegóciosSua CarreiraBlogs&ColunasPMEReforma tributáriaE-InvestidorBrasilSão PauloBlogs&ColunasInternacionalBlogs&ColunasCulturaArtesCinemaEstado da ArteLiteraturaModaMúsicaQuadrinhosSériesTeatro e DançaTelevisãoBlogs&ColunasEsportesCampeonatosBasqueteFutebolTênisUFCVelocidadeVôleiBlogs&ColunasProgramação de TVEstadão VerificaMapas interativosSaúdeAcervoAgroCiênciaBlogs&ColunasConcursosE+EducaçãoJornal do CarroLinkRecomendaMobilidadePaladarMídia & MKTSustentabilidadeSoluções AmbientaisTudo SobreVer & OuvirPodcastsTV EstadãoFotosRádio EldoradoWeb StoriesDia a diaCruzadasHoróscopoLoteriasNewslettersQuadrinhosSudokuParceirosCapituInstituto Vencer o CâncerJornal da USPMar Sem FimNeo MondoO Estado da ArteSOS EducaçãoProdutosAgência EstadoBroadcast PolíticoClassificadosEstadão Blue StudioEstradãoImóveisRecomendaEstadão RINotícias & EditoriasOpiniãoÚltimasEstadão 150 Anos150 MomentosModernizar a históriaTodo o futuro pela frenteOpinião do EstadãoNossos queridos leitoresPolíticaColuna do EstadãoBlog do Fausto MacedoBlogs&ColunasEconomiaAgronegóciosEstadão RIGovernançaIndicadoresNegóciosSua CarreiraBlogs&ColunasPMEReforma tributáriaE-InvestidorBrasilSão PauloBlogs&ColunasInternacionalBlogs&ColunasCulturaArtesCinemaEstado da ArteLiteraturaModaMúsicaQuadrinhosSériesTeatro e DançaTelevisãoBlogs&ColunasEsportesCampeonatosBasqueteFutebolTênisUFCVelocidadeVôleiBlogs&ColunasProgramação de TVEstadão VerificaMapas interativosSaúdeAcervoAgroCiênciaBlogs&ColunasConcursosE+EducaçãoJornal do CarroLinkRecomendaMobilidadePaladarMídia & MKTSustentabilidadeSoluções AmbientaisTudo SobreVer & OuvirPodcastsTV EstadãoFotosRádio EldoradoWeb StoriesDia a diaCruzadasHoróscopoLoteriasNewslettersQuadrinhosSudokuProdutosAgência EstadoBroadcast PolíticoClassificadosEstadão Blue StudioEstradãoImóveisRecomendaEstadão RIAssine EstadãoEntrarNotíciaEstadãoSão PauloEmpresário morto em queda de helicóptero em SP era sócio de empresa de apostas virtualAndré Feldman era conhecido na cidade de Americana, no interior do Estado. Ele e esposa, Juliana Elisa Maria Feldman, morreram no acidente. Filha do casal, que faz 12 anos nesta sexta, além do piloto, foram resgatados com vidaPUBLICIDADEPor José Maria Tomazela17/01/2025 | 10h05Atualização: 17/01/2025 | 14h03O empresário André Feldman, de 50 anos, que morreu na queda de um helicóptero em Caieiras, na Grande São Paulo, na noite desta quinta-feira, 16, era sócio de uma empresa de apostas virtual e conhecido em Americana, no interior de São Paulo. Sua mulher, Juliana Elisa Maria Feldman, de 49 anos, também morreu no acidente. Ela era formada em economia e sócia da empresa Bem Participações e Gestão S.A., com atuação na locação e administração de imóveis.PUBLICIDADEA filha do casal, Betina Feldman, e o piloto da aeronave, Edenilson de Oliveira Costa, sobreviveram. Betina completa 12 nesta sexta, 17. Ela passou a noite na mata junto com o piloto. Pela manhã, Edenilson tentou sair do local para pedir ajuda. Ele foi localizado pelos socorristas e indicou onde a criança estava. Além de Betina, o casal André e Juliana Feldman deixa os filhos gêmeos Enrico e Manoela, de 9 anos, que não estavam na aeronave. Vídeo: veja resgate de menina de 11 anos após queda de helicóptero na região de CaieirasPublicidadeAndré Feldman está relacionado na Receita Federal como um dos quatro sócios da empresa Big Brazil Tecnologia e Loteria S.A., aberta em abril de 2021, com sede em Americana. No cadastro consta que a empresa tem como finalidade a exploração de jogos de azar e apostas.Casal morre em queda de helicóptero em Caieiras\n\nAndré Feldman e Juliana Elisa Feldman\xa0Foto:  Reproduç ...
#   {'title': 'Dono de bet e esposa morrem em queda de helicóptero em SP; veja quem eram os ocupantes da aeronave',
#    'link': 'https://g1.globo.com/sp/sao-paulo/noticia/2025/01/17/quem-eram-os-ocupantes-do-helicoptero-que-caiu-na-cidade-de-caieiras-na-grande-sp.ghtml',
#    'snippet': 'Aeronave decolou da cidade de SP na noite de quinta-feira (16) e sumiu por volta das 20h34. Helicóptero foi localizado em Caieiras,...',
#    'date': 'há 15 horas',
#    'source': 'g1 - O portal de notícias da Globo',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRsg1MXnbq3aEYhcrdOMqtYSzyiW1wLMLBUGLr9jMW-riTWuBBXyGBv_jQ&usqp=CAI&s',
#    'position': 2,
#    'content': ' Dono de bet e esposa morrem em queda de helicóptero em SP; veja quem eram os ocupantes da aeronave | São Paulo | G1\n                   São Paulo                                       Dono de bet e esposa morrem em queda de helicóptero em SP; veja quem eram os ocupantes da aeronave    Aeronave decolou da cidade de SP na noite de quinta-feira (16) e sumiu por volta das 20h34. Helicóptero foi localizado em Caieiras, na Grande SP, às 6h15 desta sexta (17). Duas pessoas morreram.              Por Redação TV Globo e g1 SP, Letícia Dauer — São Paulo     17/01/2025 07h47    Atualizado  17/01/2025                                                         1 de 8\rO piloto Edenilson de Oliveira e o casal André Feldman e Juliana Elisa Alves Maria, que estavam no helicóptero que caiu em Caieiras, na Grande SP. — Foto: Montagem/g1/TV Globo/Grupo Liberal     O piloto Edenilson de Oliveira e o casal André Feldman e Juliana Elisa Alves Maria, que estavam no helicóptero que caiu em Caieiras, na Grande SP. — Foto: Montagem/g1/TV Globo/Grupo Liberal                O helicóptero que caiu na noite desta quinta-feira (16) em uma área de mata fechada na cidade de Caieiras, na Grande São Paulo, era ocupado por quatro pessoas.        ✅ Clique aqui para se inscrever no canal do g1 SP no WhatsApp       A aeronave foi localizada por volta das 6h15 desta sexta-feira (17). O piloto e uma menina, de 12 anos, foram socorridos com vida. Ambos foram levados para o Hospital das Clínicas, segundo a Secretaria da Segurança Pública.       Já os pais da adolescente foram encontrados mortos pelas equipes de resgate.      VÍDEO: veja o momento em que o piloto e a menina são resgatadosFOTOS: bombeiros chegam ao local da queda de helicóptero em CaieirasPILOTO: profissional que pilotava a aeronave foi resgatado conscienteADOLESCENTE: menina resgatada foi carregada nas costas por socorristas durante resgateHOSPITAL: piloto e menina são levados para o Hospital das Clínicas, em SP            Veja o que se se sabe sobre os ocupantes do helicóptero:      Piloto            2 de 8\rO piloto Edenilson de Oliveira Costa sobreviveu a queda de helicóptero em SP — Foto: Reprodução/Redes sociais     O piloto Edenilson de Oliveira Costa sobreviveu a queda de helicóptero em SP — Foto: Reprodução/Redes sociais        O piloto foi identificado como Edenilson de Oliveira Costa. Ele prestava serviço particular para a família. Natural de Dourados, no Mato Grosso do Sul, ele é casado e tem duas filhas.       Além de ter mais de 13 anos de experiência como piloto, Edenilson também tem formação em enfermagem pelo Centro Universitário de Jaguariúna, segundo informações publicadas em seu perfil no LinkedIn.      Família            3 de 8\rEmpresário André Feldman morre em acidente de helicóptero em SP — Foto: Reprodução     Empresário André Feldman morre em acidente de helicóptero em SP — Foto: Reprodução              O empresário André Feldman, de 50 anos, era CEO da BIG Brazil International Games, que tem licenciamento para operar no Brasil a marca Caesars Sportsbook — empresa de apostas virtuais conhecidas como bet.       André também era um dos proprietários do helicóptero, que pertence à empresa C & F Administração de Aeronaves LTDA.       Esposa de André, Juliana Elisa Alves Maria Feldman, de 49 anos, era empresária formada em economia pela Fundação Armando Alvares Penteado, segundo informações do LinkedIn.       O casal não resistiu aos ferimentos e morreu no local.             4 de 8\rJuliana e André Feldman, casal morto em queda de helicóptero em Caieiras — Foto: Reprodução/Grupo Liberal     Juliana e André Feldman, casal morto em queda de helicóptero em Caieiras — Foto: Reprodução/Grupo Liberal        A filha do casal, Bethina Feldman, foi resgatada com vida e completou 12 anos nesta sexta. A menina foi a responsável por indicar aos socorristas os destroços onde os pais estavam.             Além de Bethina, os empresários também têm um casal de gêmeos de 9 anos.       A  ...
#   {'title': 'Empresário morto em queda de helicóptero era dono de avião que bateu no RJ',
#    'link': 'https://veja.abril.com.br/coluna/maquiavel/empresario-morto-em-queda-de-helicoptero-era-dono-de-aviao-que-bateu-no-rj/',
#    'snippet': 'O empresário Andre Feldman, morto na noite de quinta-feira, 16, após a queda de um helicóptero em Caieiras, na Grande São Paulo, era dono de...',
#    'date': 'há 9 horas',
#    'source': 'VEJA',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThMtHRdGUrVNfHnnvO1TwPq5mn0KYdK3vVe9sl0ul5S7bxn4Lqmn3cp08&usqp=CAI&s',
#    'position': 3,
#    'content': "\n\n\n\n\n\n\n\n\n\n\nEmpresário morto em queda de helicóptero era dono... | VEJA\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nASSUNTOS EM DESTAQUE:\nÚltimas notícias\nGuerra Israel-Hamas\nRadar\nRadar Econômico\nDireto de Brasília\nRevista\n\n\n\n\n\n\n\n\n\n  Menu \n\n\n\n\nFacebook VEJA\nTwitter VEJA\nYoutube VEJA\nInstagram VEJA\n \n\n\n\n\n\n\n\n\n\n\n\nFacebook VEJA\nTwitter VEJA\nYoutube VEJA\nInstagram VEJA\n \n\n\n\n\n\n ENTRAR\n\n\n\nENTRARSAIR \n\n\n \n\nOLÁ, \n\n\n \n\nAssine\n Buscar \n\n\n\n\nBuscar\nBuscar\n\n\n\n\n\n\nVEJA Negócios\nVEJA+\nRadar\nRadar Econômico\nPolítica\nSaúde\nMundo\nCultura\nAgenda Verde\n \n\n\n\n\n\n\n\n\n×\n\n\n\n\nFacebook VEJA\nTwitter VEJA\nYoutube VEJA\nInstagram VEJA\n \n\n\n\n\n              Assine            \n\nJá sou assinanteSair Últimas notícias\nVEJA Negócios\nVEJA+\nRadar\nRadar Econômico\nRadar Jurídico\nColunas\n\nTodas as Colunas\nJosé Casado\nFernando Schüler\nMatheus Leitão\nRicardo Rangel\nVeja Gente\nNeuza Sanches\nJorge Pontes\nGiro pelo Oriente\nMurillo de Aragão\nMarcela Rahal\nMaquiavel\nMundialista\nEm Cartaz\nTela Plana\nO Som e a Fúria\nMaílson da Nóbrega\nAlexandre Schwartsman\nLuiz Gustavo Bichara\nReal Estate\nAl Vino\nConta-gotas\nVirou Viral\nLetra de Médico\nLucília Diniz\nBalanço Social\nCannabiz\nMens Sana\n\n\nAssuntos\n\nPolítica\nEconomia\nBrasil\nTecnologia\nMundo\nCiência\nEducação\nCultura\nSaúde\nComportamento\nReligião\n\n\nEsporte\nPáginas amarelas\nAgenda Verde\nVídeos\n\nGiro VEJA\nVEJA Mercado\nVEJA S/A\nAmarelas On Air\nOs Três Poderes\nPor Trás dos Números\n\n\nLivros mais vendidos\nVeja SP\nVeja RIO\nExpediente\nMinha Abril\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCONTA\n\n\nCONTEÚDOS SALVOS \n\n\nSair\n\n\n\n\n\n Oferta Relâmpago: 4 revistas pelo preço de uma!\n\n\n\n\n\n\n\n\n\n\nMaquiavel\nPor José Benedito da Silva\n\n\n\n            SEGUIR\n        \n\n\n            SEGUINDO\n        \n \n\n\n\n\n\n\n\nA política e seus bastidores. Com Laísa Dall'Agnol, Bruno Caniato, Valmar Hupsel Filho, Isabella Alonso Panho e Ramiro Brites. Este conteúdo é exclusivo para assinantes.\n\n\n\n\n\n\n\n\n\n\nBrasil \nEmpresário morto em queda de helicóptero era dono de avião que bateu no RJ\nAeronave de André Feldman atravessou a pista e colidiu com uma grade em Angra dos Reis em outubro de 2024\n\n    Por Ramiro Brites\n\n\n\n                        SEGUIR\n                    \n\n\n                        SEGUINDO\n                    \n \n      Atualizado em 17 jan 2025, 16h19 - Publicado em 17 jan 2025, 14h11    \n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n Juliana e André Feldman: casal morreu em queda de helicóptero na noite de quinta-feira\xa0(Redes sociais/Reprodução)\n\nContinua após publicidade\n\n\n\n\n\n\n\n\n\nO empresário André Feldman, morto na noite de quinta-feira, 16, após a queda de um helicóptero em Caieiras, na Grande São Paulo, era dono de um avião que colidiu ao sair da pista e pousar no aeroporto de Angra dos Reis, no litoral sudoeste do Rio de Janeiro. O acidente ocorreu em 12 de outubro do ano passado, o último feriado do Dia de Nossa Senhora Aparecida.\nSegundo informações do Centro de Investigação e Prevenção de Acidentes Aeronáuticos (Cenipa), a aeronave, um bimotor da fabricante Cessna Aircraft produzido em 1993, transportava o piloto e mais três passageiros. Todos saíram ilesos, mas não foram identificados. “A aeronave decolou do Aeródromo Americana (SDAI), Americana, SP, com destino Ao aeródromo Angra dos Reis (SDAG), Angra dos Reis, RJ, a fim de realizar voo privado, com um tripulante e três passageiros a bordo. Durante o pouso, a aeronave excedeu os limites da pista, ultrapassando a cabeceira oposta”, diz o relatório preliminar do Sistema de Investigação e Prevenção de Acidentes Aeronáuticos (Sipaer).\n\n\n\n\n\n Propriedade de André Feldman, jatinho colidiu ao pousar em Angra dos Reis no an ...
#   {'title': 'Quem é o piloto do helicóptero do empresário André Feldman que caiu em SP',
#    'link': 'https://www.cnnbrasil.com.br/nacional/sudeste/sp/quem-era-o-piloto-do-helicoptero-do-empresario-andre-feldman-que-caiu-em-sp/',
#    'snippet': 'Aeronave caiu no Morro do Tico Tico, em Caieiras (SP)',
#    'date': 'há 13 horas',
#    'source': 'CNN Brasil',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRXCa_qvj79iOmvzIVus4UNxZ9ORD75VXaFRL2Htp3Txu3vBTgEWQiBLME&usqp=CAI&s',
#    'position': 4,
#    'content': '               Quem é o piloto do helicóptero do empresário André Feldman que caiu em SP | CNN Brasil                                                       Ao Vivo    COP 30    Política    Política    Notícias     William Waack      Internacional    Nacional    Economia    Economia    Notícias     Investimentos     Mercado     Cotações     Loterias    Loterias   Mega Sena   Quina   Lotofacil   Lotomania   Duplasena   Loteria Federal   Timemania   Loteca   Dia de Sorte   Super Sete       CNN Money    Entretenimento    Saúde    Esportes    Esportes    Notícias     Olimpíadas     Futebol    Futebol   Brasileirão      Basquete     Automobilismo     Tênis     E-Sports      Tecnologia    Lifestyle    Viagem & Gastronomia    Auto    Educação    CNN Talks    Fórum CNN    Blogs CNN    Colunas CNN       Programação    Equipe CNN Brasil    Newsletters    Colunistas       Sobre a CNN    Política de Privacidade    Termos de Uso    Fale com a CNN    Distribuição do Sinal    Faça parte da Equipe CNN         Ao vivo    Política    WW    Economia    Esportes    Pop    Viagem & Gastronomia                               seg - sex    Apresentação     Ao vivo            AO VIVO: BASTIDORES CNN - 17/01/2025             Switch      A seguir                        Quem é o piloto do helicóptero do empresário André Feldman que caiu em SP   Aeronave caiu no Morro do Tico Tico, em Caieiras (SP)    Da CNN      17/01/2025 às 09:49 | Atualizado 17/01/2025 às 10:51                 Trocar imagemTrocar imagem   1 de 4    O piloto foi resgatado com vida do acidente junto de uma criança de 12 anos\xa0 • Reprodução          Trocar imagemTrocar imagem   2 de 4    O piloto foi resgatado com vida do acidente junto de uma criança de 12 anos          Trocar imagemTrocar imagemTrocar imagem   3 de 4    O piloto foi resgatado com vida do acidente junto de uma criança de 12 anos • Reprodução/ Redes sociais     Trocar imagemTrocar imagem           Trocar imagemTrocar imagemTrocar imagem   4 de 4    O piloto foi resgatado com vida do acidente junto de uma criança de 12 anos                                      visualização default visualização full visualização grid    Compartilhar matéria                                    Copiar Link    Edenilson de Oliveira Costa, o piloto do helicóptero do empresário André Feldman, que caiu em Caieiras, nesta sexta-feira (17) no interior de São Paulo, é um profissional experiente com mais de 15 anos de atuação na área.O piloto foi resgatado com vida do acidente junto de uma criança de 11 anos.Nascido em Dourados, Edenilson é casado há 25 anos e pai de duas filhas. Reside em Paulínia, no interior de São Paulo e, de acordo com um amigo presente no local do acidente, pilotava o helicóptero da família Feldman.              Trocar imagemTrocar imagem   1 de 10    Helicóptero cai na região de Caieiras, no interior de São Paulo. Duas pessoas morrem e dois são resgatados com vida • Defesa Civil de SP          Trocar imagemTrocar imagem   2 de 10    Helicóptero cai na região de Caieiras, no interior de São Paulo. Duas pessoas morrem e dois são resgatados com vida • Defesa Civil de SP          Trocar imagemTrocar imagemTrocar imagem   3 de 10    Helicóptero cai na região de Caieiras, no interior de São Paulo. Duas pessoas morrem e dois são resgatados com vida • Defesa Civil de SP     Trocar imagemTrocar imagem           Trocar imagemTrocar imagemTrocar imagem   4 de 10    Helicóptero cai na região de Caieiras, no interior de São Paulo. Duas pessoas morrem e dois são resgatados com vida • Defesa Civil de SP          Trocar imagemTrocar imagem   5 de 10    Helicóptero cai na região de Caieiras, no interior de São Paulo. Duas pessoas morrem e dois são resgatados com vida • Defesa Civil de SP          Trocar imagemTrocar imagemTrocar imagem   6 de 10    Helicóptero cai em Caieiras, na Grande São Paulo • Reprodução TV Globo     Trocar imagemTrocar imagem           Trocar imagemTrocar imagemTrocar imagem   7 de 10    Piloto de helicópt ...
#   {'title': 'André Feldman, empresário do poker brasileiro, e esposa morrem em acidente aéreo',
#    'link': 'https://superpoker.com.br/noticias/andre-feldman-empresario-do-poker-brasileiro-e-esposa-morrem-em-acidente-aereo',
#    'snippet': 'André Feldman e a esposa Juliana foram vítimas fatais de um acidente aéreo nesta sexta (17). Ele era empresário com atuação no poker.',
#    'date': 'há 10 horas',
#    'source': 'SuperPoker',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGe3Hl5a-e-HjPnt-JTiXgsLHW9Rjkp3HQ9awnQlkg940Le85jeYDk6y0&usqp=CAI&s',
#    'position': 5,
#    'content': 'André Feldman, empresário do poker, e mulher morrem em acidente aéreo Notícias mais recentes COBERTURAS AO VIVO WSOP LAS VEGAS CLUBES POKERCAST COMO JOGAR POKER O MAIS VISTO WSOP LAS VEGASBrands GGPOKER  888POKER POKERSTARS PIXPOKER SUPREMAEvents BSOP WSOP BRAZIL LAPTClubes H2 CLUB BRASIL Casino Dicas de PokerSiga-nosContato:   contato@gruposuperpoker.com.brO maior portal sobre Poker da América Latina, saiba tudo o queacontece nos feltros, agenda de torneios e a vida dos profissionais.Sobre NósStaffTermos e CondiçõesPrivacidadePolítica EditorialAd Choices| CONTATOSuperpoker, assim como Futbol Sites, é uma empresa pertencente à Better Collective. Todos os direitos reservados.+18 | Jogue com responsabilidade | Aplicam-se os Termos e Condições | Conteúdo ComercialA adesão a uma das ofertas apresentadas nesta página poderá resultar em um pagamento ao Superpoker. Isso pode afetar como e onde as casas de apostas aparecem na página e a ordem em que aparecem, mas não influencia nossas avaliações.Notícias mais recentesCOBERTURAS AO VIVOWSOP LAS VEGASCLUBESPOKERCASTCOMO JOGAR POKERBrandsGGPOKER 888POKERPOKERSTARSPIXPOKERSUPREMAEventsBSOPWSOP BRAZILLAPTClubesH2 CLUB BRASIL Casino Dicas de PokerPokerAndré Feldman, empresário do poker brasileiro, e esposa morrem em acidente aéreoFilha do casal e piloto do helicóptero sobreviveram em Caieiras (SP)\nDois campeões, forras pesadas e gamão: o fim inusitado do Borgata Winter Poker OpenTorneio solidário na Flórida termina com título do craque Michael Mizrachi; confiraPor Gabriel EliasAtualizada em 17/01/2025 - 13:07hs BRT  whatsappAndré Feldman e Juliana Alves Feldman não resistiram (Foto: Reprodução/Redes sociais)\nPor Gabriel EliasAtualizada em 17/01/2025 - 13:07hs BRT  whatsappO noticiário brasileiro acordou nesta sexta-feira (17) com a trágica queda de helicóptero na região do município de Caieiras (SP), na Grande São Paulo. O empresário André Feldman, de 50 anos, e sua esposa Juliana Alves Feldman, de 49, faleceram no acidente aéreo. André era um empresário com atuação no poker brasileiro e no universo das apostas.\nVeja tambémVictor Lucas vence Bounty Hunters Daily Main em pódio 100% brasileiro\nNo acidente, sobreviveram a filha do casal, Bethina, de 11 anos, e o piloto Edenílson de Oliveira Costa. André Feldman era CEO da BIG Brazil, empresa do ramo das apostas que obteve licenciamento da marca Caesars Sportsbook no Brasil. A firma é responsável pelo ingresso da gigante dos cassinos no mercado brasileiro, regulamentado recentemente pelo Governo Federal.\nA BIG Brazil foi fundada em 2021, com sede em Americana (SP), cidade onde vive a família Feldman e destino previsto do voo, que saiu do Aeroporto Campo de Marte, em São Paulo (SP), mas se acidentou ainda na noite de quinta-feira (16). Antes de assumir essa empresa, André foi atuante no poker brasileiro, com grande relevância ao trazer a marca WSOP para o país, realizando etapas da WSOP Brazil.\nVeja tambémPopular operador de poker recebe multa milionária na Holanda; entenda o caso\nAlém de comandar a BIG Brazil, André também era sócio de uma empresa de administração de aeronaves, da qual o helicóptero do acidente pertencia. Era uma aeronave modelo EC 130 B4, de matrícula PR-WVT, fabricada em 2001 pela Eurocopter France e adquirida pela firma em 2023. O empresário ainda foi um dos fundadores da Associação Nacional de Jogos e Loterias.\nO prefeito de Americana, Chico Sardelli, lamentou a tragédia nas redes sociais. “Recebi com tristeza a notícia da morte do casal André e Juliana Feldman (…) Dois americanenses que se despedem de maneira trágica e que deixarão um legado de trabalho, dedicação e amizade”, escreveu. O governador de São Paulo, Tarcísio de Freitas, também prestou condolências. “Infelizmente começamos o dia com a triste notícia da morte de um casal vítima da queda de um helicóptero (…) Meus sentimentos a familiares e amigos neste momento”, afirmou.\nOs resgatados no acidente, Bethina e Edenílson, foram encaminhados p ...
#  'UFC': [{'title': 'UFC: Tsarukyan se lesiona na véspera, e Moicano o substitui em disputa de cinturão',
#    'link': 'https://ge.globo.com/combate/noticia/2025/01/17/ufc-tsarukyan-se-lesiona-na-vespera-e-moicano-o-substitui-em-disputa-de-cinturao.ghtml',
#    'section': 'Islam Makhachev no UFC 311',
#    'date': 'há 7 horas',
#    'source': 'GE',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQnu0XqxlqR0ZIZYDXT2SBmahblf_TcJ0vQgEOWbV5AUUFHXXL0DNI9iUg&usqp=CAI&s',
#    'position': 1,
# ...
#   {'title': 'Rival de Poatan é vaiado em coletiva de imprensa no UFC; entenda',
#    'link': 'https://www.umdoisesportes.com.br/colunas-e-blogs/direto-do-octogono/poatan-rival-vaiado-ufc/',
#    'snippet': 'Rival de Alex Poatan no UFC, Jamahal Hill foi vaiado em coletiva de imprensa nesta semana. Leia mais no UmDois Esportes!',
#    'date': 'há 7 horas',
#    'source': 'Um Dois Esportes',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT_uWkyg1yuoZwmJicCGNtFTASgqW9iq7S42SJh1oznyvEkTm4h7LMYPus&usqp=CAI&s',
#    'position': 2,
#    'content': 'Rival de Poatan é vaiado em coletiva de imprensa no UFCMenuÚltimasMMARival de Poatan é vaiado em coletiva de imprensa no UFC; entendaPorDiogo Souza17/01/2025 15:29 - Atualizado: 17/01/2025 15:30Alex Poatan x Jamahal Hill no UFC. | Foto: IconSportA coletiva de imprensa do UFC 311, realizada na última quinta-feira, em Los Angeles, contou com momentos divertidos e tensos. Um destes momentos foi protagonizado pelo norte-americano Jamahal Hill, desafeto do brasileiro Alex Poatan.Ao ser chamado no palco, o ex-campeão foi vaiado pelo público presente. Logo depois, quando foi questionado por um jornalista sobre a reação dos fãs, Hill foi novamente vaiado pelos torcedores. + Mais notícias do UFCUma parcela dos fãs ainda começou a gritar a palavra "chama", que ficou mundialmente conhecida por ser uma expressão utilizada por Alex Poatan, campeão dos meio-pesados do UFC. Por outro lado, o adversário do Jamahal Hill no UFC 311 deste sábado (18), a partir das 20h (horário de Brasília), em Los Angeles, será o tcheco Jiri Prochazka, que também protagonizou um momento de destaque na coletiva. Em apoio a um fã com câncer, Prochazka raspou o seu tradicional corte de cabelo samurai. O lutador também destacou que pretende doar cerca de 50 mil dólares para apoiar as pesquisas sobre o câncer. UFC 31118 de janeiro de 2025, às 20h (de Brasília), em Los Angeles (EUA)CARD PRINCIPAL:Peso-leve: Islam Makhachev x Arman TsarukyanPeso-galo: Merab Dvalishvili x Umar NurmagomedovPeso-meio-pesado: Jiri Prochazka x Jamahal HillPeso-leve: Beneil Dariush x Renato MoicanoPeso-médio: Kevin Holland x Reinier de RidderCARD PRELIMINAR:Peso-galo: Payton Talbott x Raoni BarcelosPeso-pesado: Jailton Almeida x Serghei SpivacPeso-meio-pesado: Billy Elekana x Bogdan GuskovPeso-leve: Grant Dawson x Carlos Diego FerreiraPeso-médio: Zachary Reese x Azamat BekoevPeso-galo: Karol Rosa x Ailín PérezPeso-galo: Rinya Nakamura x Muin GafurovPeso-galo: Ricky Turcios x Benardo SopajPeso-mosca: Tagir Ulanbekov x Clayton CarpenterSiga o UmDois EsportesyoutubexfacebookinstagramVeja também:Palpites Campeonato Paranaense 2025: as melhores dicas de apostaTribunal rejeita pedido e confirma eliminação do Athletico na CopinhaMercado da Bola: Negociações nesta sexta-feira (17) do futebol brasileiroUFC 311: Saiba quem é o brasileiro que pode ganhar cinturão peso-leve Diogo SouzaEditor Diogo SouzaEditorProfissional na área de Comunicação/Jornalismo há 16 anos - sendo 14 na empresa Editora O Estado do Paraná (GRPCOM), com experiência na produção e edição de mídias impressas e digitais. Iniciei como estagiário na Editora O Estado ...+ Notícias sobre Direto do OctógonoChance de ouro!UFC 311: Saiba quem é o brasileiro que pode ganhar cinturão peso-leveMMAUFC 311: Makhachev x Moicano - Dicas, palpites e prognósticos - 18/01/2025MMABOMBA! Brasileiro ganha chance pelo cinturão no UFC 311 de última horaTudo SobreMMAUFCUm Dois Esportes>Colunas e Blogs>Direto do Octógono>Rival de Poatan é vaiado em coletiva de imprensa ...Aviso Legal. Nossa página oferece cobertura jornalística esportiva nacional de qualidade, contando com um time de especialistas na produção de conteúdo imparcial e na coleta e compartilhamento de informações relevantes sobre apostas esportivas online e o jogo responsável. Em nosso conteúdo, fazemos marketing e o uso de links de afiliação de apostas esportivas online. Isso significa que, ao clicar, você poderá ser redirecionado a um de nossos anunciantes. Antes de adquirir qualquer produto ou serviço, certifique-se de que se trata de site licenciado em sua jurisdição e de atender todas as exigências legais aplicáveis ao jogo responsável. Aposte com segurança e responsabilidade.FacebookTwitterInstagramYoutubeUmDois EsportesSobreDiretrizes JornalísticasPolítica de PrivacidadeTermos de UsoFale ConoscoNotíciasSobreAthleticoCoritibaParaná ClubeMais EsportesOpiniãoColunas e Blogs© 2025 – UmDois Esportes. Todos os direitos reservados.'},
#   {'title': 'UFC Londres anuncia oficialmente luta entre Leon Edwards e promessa dos meio-médios',
#    'link': 'https://www.msn.com/pt-br/esportes/lutas/ufc-londres-anuncia-oficialmente-luta-entre-leon-edwards-e-promessa-dos-meio-m%C3%A9dios/ar-AA1xp38n',
#    'snippet': 'O ex-campeão dos meio-médios (até 77kg.) do UFC Leon Edwards fará oficialmente sua primeira aparição desde que perdeu seu título em julho do ano passado,...',
#    'date': 'há 1 hora',
#    'source': 'MSN',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRRy6_8hsKl5jCBdycZ1WPVyiiCrYysAOfLZgOe8TBnwKESBJNtp0nH50A&usqp=CAI&s',
#    'position': 3,
#    'content': '\n\n\n\n\n\nMSN\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'},
#   {'title': 'UFC 311 abre pay-per-views de 2025 com duas disputas de cinturão; saiba mais',
#    'link': 'https://www.terra.com.br/esportes/lutas/ufc-311-abre-pay-per-views-de-2025-com-duas-disputas-de-cinturao-saiba-mais,2e1d9b110c7bf883d64e364c471eb0b59haj55es.html',
#    'snippet': 'O primeiro pay-per-view de 2025 será o UFC 311, marcado para este sábado (18) em Los Angeles, já reserva muitas emoções.',
#    'date': 'há 2 horas',
#    'source': 'Terra',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlzPjAf1IJC6oOiJuwcf_Ug8NombHaXIOANdM1j1afWvWT9T0i5vo2V_k&usqp=CAI&s',
#    'position': 4,
#    'content': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nUFC 311 abre pay-per-views de 2025 com duas disputas de cinturão; saiba mais\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nScript = https://s1.trrsf.com/update-1736967909/fe/zaz-ui-t360/_js/transition.min.js\nScript = https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-7059064278943417\n\n\n\n\n\n\n\n\n\n\n\n\n\nIr ao conteúdo\n\n\n\n\n\n\n\nPágina principal\n\n\n\n\n\n\n                                                                Terra Mail\n                            \n\n\n\n                                                                Combo de Cursos\n                            \n\n\n\n                                                                Vivo Fibra\n                            \n\n\n\n                                                                Amazon Prime\n                            \n\n\n\n                                                                Terra Astral\n                            \n\n\n\n                                                                Terra Meu Negócio\n                            \n\n\n\n                                                                Central do Assinante\n                            \n\n\n\n\nE-mail\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPUBLICIDADE\n\n\n\n\n\n\n                    Capa\n                \n\n\n\n\n\n\n                    Esportes\n                \n\n\n\n\n\n\n                    Lutas\n                \n\n\n\n\n\n\n\n\n\n\n\n\nLutas\n\n\n\n \n\n\n\n\n\n\n\n\n\nUFC 311 abre pay-per-views de 2025 com duas disputas de cinturão; saiba mais\n\n\nO primeiro pay-per-view de 2025 será o UFC 311, marcado para este sábado (18) em Los Angeles, já reserva muitas emoções\n\n\n\n\nPor:\nEsporte News Mundo\n\n\n\n\n\n\n\n\n\n17 jan\n2025\n - 21h03\n\n\n                                                                                                            (atualizado às 21h03)\n                                                                    \n\n\n\nCompartilhar\n\n\n\n\nExibir comentários\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFoto: Esporte News Mundo\n\n\n\nO primeiro pay-per-view de 2025 será o UFC 311, marcado para este sábado (18) em Los Angeles, já reserva muitas emoções, com duas disputas de cinturão e presença brasileira no octógono mais famoso do mundo.Quem quiser saber de tudo o que acontecerá no card deste final de semana e o que fazer para acompanhar o evento, o Portal Esporte News Mundo oferecerá as informações necessárias para todos os fãs de MMA.\n\nNotícias relacionadas\n\n\n\nBrasileiros levam primeiros bônus do UFC em 2025 após vitórias; confira\n\n\n\nMackenzie Dern espera ser \'campeã dominante\' e diz não ter pressa por title shot\n\n\n\nPFL anuncia fim de contrato com Patrício Pitbull; lutador reage\n\n\nMoicano a caminho do ouroO main event do UFC 311 seria originalmente entre Islam Makhachev e Arman Tsarukyan, que lutariam pelo cinturão dos leves. Mas o armênio, desafiante ao título, lesionou as costas na véspera da luta e foi retirado do evento, deixando o campeão sem adversário.A resolução foi rápida e Dana White escalou o brasileiro Renato Moicano para fazer a luta principal, este que enfrentaria Beneil Dariush no card deste sábado. Com isso, a grande chance do Brasil voltar a ter um campeão na categoria surge de forma inesperada, contra um dos mais dominantes donos do cinturão.Mais um da família?A família Nurmagomedov poderá ter mais um campeão em breve. Primo de Khabib, Umar continua o legado de seus parentes, tendo vencido todas as suas 18 lutas como profissional no MMA e tendo a chance de colocar sua equipe mais uma vez no lugar mais alto do esporte se vencer o título dos galos do UFC.Mas, para que isto se torne realidade, terá que passar pelo campeão Merab Dvalishvili. O georgiano, que conquistou o cinturão depois de vencer Sean O\'Malley, chegou a dizer em várias oportunidades  ...
#   {'title': 'Lutadora pede desculpa ao marido por tapa na cara após derrota no UFC',
#    'link': 'https://agfight.com/ufc/lutadora-pede-desculpa-ao-marido-por-tapa-na-cara-apos-derrota-no-ufc/',
#    'snippet': 'No último sábado (11), Victoria Dudakova chocou a comunidade do MMA ao protagonizar uma cena polêmica no UFC Vegas 101.',
#    'date': '2 dias atrás',
#    'source': 'Ag. Fight',
#    'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0SFewdJV6P7ACBRc_X5sTBYsrfefZROtbroFRNOO-gkpSd_fi-Ta5iH8&usqp=CAI&s',
#    'position': 5,
#    'content': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLutadora pede desculpa ao marido por tapa na cara após revés no UFC - Ag. Fight – MMA, UFC, Boxe e Mais\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\nQuem somos\nNotícias\nRanking do UFC\nGaleria de Fotos\nVídeos\nContato\n \n\n\nSiga-nos\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAg. Fight – MMA, UFC, Boxe e Mais\n\n\n\n\n\n\n\n\n\n\n\n\nSiga-nos\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\nQuem somos\nNotícias\nRanking do UFC\nGaleria de Fotos\nVídeos\nContato\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\nDudakova vive má fase no MMA - Louis Grasse/PxImages\n\n\n\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tUFC\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nLutadora pede desculpa ao marido por tapa na cara após derrota no UFC\n\n\n\n\n\n\npor Rodrigo Tannuri \n\n\n\n\n\n15/01/2025\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNo último sábado (11), Victoria Dudakova chocou a comunidade do MMA ao protagonizar uma cena polêmica no UFC Vegas 101. No evento, a russa mediu forças com Fatima Kline, acabou nocauteada no segundo round e, irritada com a derrota, deu um tapa na cara de um dos seus treinadores. Ciente da repercussão negativa de sua ação, a atleta se mostrou arrependida por ter atacado o membro da sua equipe, que também é seu marido.\nNa última terça-feira (14), Dudakova utilizou sua conta oficial no ‘Instagram’ para se desculpar com o marido e com os fãs de MMA que se sentiram ofendidos com a cena. Em seu posicionamento, a lutadora revelou que estava se sentindo abandonada, profissionalmente, e, ao ser derrotada pela segunda vez no UFC, admitiu que não conseguiu conter sua frustração e seu nervosismo. \nNo perfil, a russa publicou uma foto sorrindo junto ao marido e treinador e lamentou profundamente o ocorrido. Ciente das duras críticas que recebeu de parte da comunidade do MMA, Victoria deu a entender que, a partir de agora, adotará uma postura profissional completamente diferente da que mostrou no evento.\n“As emoções se acalmaram um pouco. Em primeiro lugar, gostaria de pedir desculpa ao meu marido e treinador. Fiquei chateada, porque, em um momento tão difícil, ele se afastou de mim e não quis entrar no octógono. Isso não é uma desculpa e não estou procurando uma desculpa. Fiz a coisa errada, não consegui controlar minhas emoções. Dei um mau exemplo para os atletas e para a geração mais jovem. Também quero me desculpar com os fãs do esporte. Obrigado a todos que permanecem comigo em uma situação tão difícil”, escreveu a atleta.\nRegistro de Dudakova no MMA\nVictoria Dudakova, de 25 anos, é uma promessa do MMA, mas vem tendo dificuldade para se firmar no UFC. A russa iniciou sua trajetória\xa0 no esporte em 2020 e estreou na companhia em 2023. Nela, a atleta venceu as duas primeiras lutas que disputou e perdeu as outras duas, ou seja, viu sua invencibilidade na modalidade chegar ao fim e entrou em má fase.\n\n\n\xa0\n\n\n\n\n\n\n\n\n\n\nVer essa foto no Instagram\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\nUma publicação compartilhada por Victoria Dudakova (@victoriadudakova)\n\n\n\n\n \nAssuntos relacionadosDudakovaMMAtapatapa na caraUFCufc vegas 101victoria dudakova\n\n\n\n\n\n\n \n\n\nRodrigo Tannuri\n\n\n\n\n\n\n\n\nJornalista formado, especializado em MMA. Também acompanho boxe, boxe sem luvas, boxe de celebridades e WWE.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPublicidade\n\n\n\n \nPesquisa\n\n\n \nPublicidade\n \n\n\n\n\n\n\r\n Mais Lidas\n\n\n\r\n Videos\n\n\n\n\n\n\n\n\n \n\n\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\tEntrevistas\t\t\t\t\t\t\t\t\t\t\t\t\nCésar Almeida se solidariza com rival após nocauteá-lo de forma assustadora no UFC\n\n\n\n\n\n\n\n\n \n\n\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\tNotícias\t\t\t\t\t\t\t\t\t\t\t\t\nKhabib Nurmagomedov critica funcionária após ser retirado de voo nos EUA: “Rude”\n\ ...

# %%
from IPython.display import Markdown
import smtplib # Para enviar email
from email.message import EmailMessage #pra deixar no formato que envia email

from pydantic import BaseModel, Field
from typing import List

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

model_name_openai = "gpt-4o-2024-08-06" # Garante 100% do output em JSON

llm_openai = ChatOpenAI(
    model=model_name_openai, # 100% json output
    temperature=0,
)

system_prompt = """
Você é um assistente de IA muito prestativo que vai auxiliar um jornalista a classificar notícias que falam especificamente de futebol. Você precisa classificar a notícia como YES ou NO, dependendo se o texto fala de futebol ou não.
"""

prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt), 
            ("human", "query do usuário: \n\n {query}")
        ]
)

class GetSchema(BaseModel):
    """Schema de futebol"""
    
    resultado: str = Field(description="YES caso o texto fale de FUTEBOL e NO caso contrário", examples=['YES', 
                                                                                                    'NO'])

news = contents_news
noticias_futebol = {}

llm_openai_with_tools_extraction = llm_openai.bind_tools([GetSchema]) #, strict=True)
chain_openai_structured_extraction = prompt | llm_openai_with_tools_extraction
for assunto, noticias in news.items():
    for materia in noticias:
        content = (materia['content'])
        response = chain_openai_structured_extraction.invoke({"query": content})
        result = response.tool_calls[0]['args']['resultado']
        if result == "YES":
            noticias_futebol[assunto] = noticias

print(noticias_futebol)
# Out:
# {}

# %% [markdown]
# ## Conclusão:
#
# Em primeiro lugar, é possível observar a utilidade de construir ferramentas (Tools). Elas são capazes de facilitar a reutilização de código, a paralelização de tarefas, a observabilidade e o monitoramento de tarefas. Por fim, vamos utilizar essas ferramentas para construir um agente que irá pesquisar tendências via ``Google Trends`` e retornar uma lista de conteúdos que estão em alta, a partir de pesquisas na web.
